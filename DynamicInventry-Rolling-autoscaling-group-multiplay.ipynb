# %% [markdown]
# ## rolling autoscaling group

# %%
$ cat hosts 
localhost ansible_connection=local ansible_python_interpreter=/usr/bin/python3

# %%
# ansible-galaxy collection install amazon.aws

Process install dependency map
Starting collection install process
Installing 'amazon.aws:4.0.0' to '/root/.ansible/collections/ansible_collections/amazon/aws'

# %%
# userdata of launch configuration

#!/bin/bash

yum install httpd php git -y
rm -rf /var/www/website/
git clone https://github.com/jinumona/aws-elb-site.git  /var/www/website/
cp -rf /var/www/website/*  /var/www/html/
chown -R apache:apache /var/www/html
systemctl restart httpd.service
systemctl enable httpd.service
pip3 install  boto3 botocore

# %% [markdown]
# #### on Ansible/Master

# %% [markdown]
# on master ansible machine
# as ec2 user run
#
# pip3 install ansible

# %%
$ cat main.yml 

---
- name: "Getting AutoScaling Instance Details"
  hosts: localhost
  vars:
    access_key: "AKIAXQMPZJZXGR6OFJWL"
    secret_key: "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"
    region: "ap-south-1"
    asg_name: "myapp-asg"
  tasks:
    - name: "Fetching Instance Details Of asg {{ asg_name }}"
      amazon.aws.ec2_instance_info:
        aws_secret_key: "{{ secret_key }}"
        aws_access_key: "{{ access_key }}"
        region: "{{ region }}"
        filters:
          "tag:aws:autoscaling:groupName": "{{ asg_name }}"
          instance-state-name: [ "running"]
      register: asginstance_info
        
    - debug:
        var: asginstance_info

# %%
$ ansible-playbook -i hosts main.yml

# %%
[DEPRECATION WARNING]: Ansible will require Python 3.8 or newer on the controller starting with Ansible 2.12. Current version: 3.7.10 (default, Jun  3 
2021, 00:02:01) [GCC 7.3.1 20180712 (Red Hat 7.3.1-13)]. This feature will be removed from ansible-core in version 2.12. Deprecation warnings can be 
disabled by setting deprecation_warnings=False in ansible.cfg.

PLAY [Getting AutoScaling Instance Details] ***************************************************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
ok: [localhost]

TASK [Fetching Instance Details Of asg myapp-asg] *********************************************************************************************************
ok: [localhost]

TASK [Debugging asginfo] **********************************************************************************************************************************
ok: [localhost] => {
    "asginstance_info": {
        "changed": false,
        "failed": false,
        "instances": [
            {
                "ami_launch_index": 0,
                "architecture": "x86_64",
                "block_device_mappings": [
                    {
                        "device_name": "/dev/xvda",
                        "ebs": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "delete_on_termination": true,
                            "status": "attached",
                            "volume_id": "vol-0da77109d288c431f"
                        }
                    }
                ],
                "capacity_reservation_specification": {
                    "capacity_reservation_preference": "open"
                },
                "client_token": "29260722-3c50-e379-c734-865d642dbe9d",
                "cpu_options": {
                    "core_count": 1,
                    "threads_per_core": 1
                },
                "ebs_optimized": false,
                "ena_support": true,
                "enclave_options": {
                    "enabled": false
                },
                "hibernation_options": {
                    "configured": false
                },
                "hypervisor": "xen",
                "image_id": "ami-08df646e18b182346",
                "instance_id": "i-0dfe8858c515fff0e",
                "instance_type": "t2.micro",
                "key_name": "devops-class",
                "launch_time": "2022-07-04T09:33:50+00:00",
                "maintenance_options": {
                    "auto_recovery": "default"
                },
                "metadata_options": {
                    "http_endpoint": "enabled",
                    "http_protocol_ipv6": "disabled",
                    "http_put_response_hop_limit": 1,
                    "http_tokens": "optional",
                    "instance_metadata_tags": "disabled",
                    "state": "applied"
                },
                "monitoring": {
                    "state": "disabled"
                },
                "network_interfaces": [
                    {
                        "association": {
                            "ip_owner_id": "amazon",
                            "public_dns_name": "ec2-13-233-223-21.ap-south-1.compute.amazonaws.com",
                            "public_ip": "13.233.223.21"
                        },
                        "attachment": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "attachment_id": "eni-attach-0b7ae5ab48e77715a",
                            "delete_on_termination": true,
                            "device_index": 0,
                            "network_card_index": 0,
                            "status": "attached"
                        },
                        "description": "",
                        "groups": [
                            {
                                "group_id": "sg-04182bdfbfa17d831",
                                "group_name": "freedom"
                            }
                        ],
                        "interface_type": "interface",
                        "ipv6_addresses": [],
                        "mac_address": "02:d8:d7:18:f9:58",
                        "network_interface_id": "eni-07f1e0bf9ccaf9b55",
                        "owner_id": "516234497646",
                        "private_dns_name": "ip-172-31-40-62.ap-south-1.compute.internal",
                        "private_ip_address": "172.31.40.62",
                        "private_ip_addresses": [
                            {
                                "association": {
                                    "ip_owner_id": "amazon",
                                    "public_dns_name": "ec2-13-233-223-21.ap-south-1.compute.amazonaws.com",
                                    "public_ip": "13.233.223.21"
                                },
                                "primary": true,
                                "private_dns_name": "ip-172-31-40-62.ap-south-1.compute.internal",
                                "private_ip_address": "172.31.40.62"
                            }
                        ],
                        "source_dest_check": true,
                        "status": "in-use",
                        "subnet_id": "subnet-0c76e66f9fa438375",
                        "vpc_id": "vpc-04c6b7bd99f05c144"
                    }
                ],
                "placement": {
                    "availability_zone": "ap-south-1a",
                    "group_name": "",
                    "tenancy": "default"
                },
                "platform_details": "Linux/UNIX",
                "private_dns_name": "ip-172-31-40-62.ap-south-1.compute.internal",
                "private_dns_name_options": {
                    "enable_resource_name_dns_a_record": false,
                    "enable_resource_name_dns_aaaa_record": false,
                    "hostname_type": "ip-name"
                },
                "private_ip_address": "172.31.40.62",
                "product_codes": [],
                "public_dns_name": "ec2-13-233-223-21.ap-south-1.compute.amazonaws.com",
                "public_ip_address": "13.233.223.21",
                "root_device_name": "/dev/xvda",
                "root_device_type": "ebs",
                "security_groups": [
                    {
                        "group_id": "sg-04182bdfbfa17d831",
                        "group_name": "freedom"
                    }
                ],
                "source_dest_check": true,
                "state": {
                    "code": 16,
                    "name": "running"
                },
                "state_transition_reason": "",
                "subnet_id": "subnet-0c76e66f9fa438375",
                "tags": {
                    "Name": "myapp-asg",
                    "aws:autoscaling:groupName": "myapp-asg"
                },
                "usage_operation": "RunInstances",
                "usage_operation_update_time": "2022-07-04T09:33:50+00:00",
                "virtualization_type": "hvm",
                "vpc_id": "vpc-04c6b7bd99f05c144"
            },
            {
                "ami_launch_index": 0,
                "architecture": "x86_64",
                "block_device_mappings": [
                    {
                        "device_name": "/dev/xvda",
                        "ebs": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "delete_on_termination": true,
                            "status": "attached",
                            "volume_id": "vol-03d61f6f3afa81395"
                        }
                    }
                ],
                "capacity_reservation_specification": {
                    "capacity_reservation_preference": "open"
                },
                "client_token": "e0e60722-3c4f-eded-1083-403ed45c797b",
                "cpu_options": {
                    "core_count": 1,
                    "threads_per_core": 1
                },
                "ebs_optimized": false,
                "ena_support": true,
                "enclave_options": {
                    "enabled": false
                },
                "hibernation_options": {
                    "configured": false
                },
                "hypervisor": "xen",
                "image_id": "ami-08df646e18b182346",
                "instance_id": "i-034707f95171eb446",
                "instance_type": "t2.micro",
                "key_name": "devops-class",
                "launch_time": "2022-07-04T09:33:50+00:00",
                "maintenance_options": {
                    "auto_recovery": "default"
                },
                "metadata_options": {
                    "http_endpoint": "enabled",
                    "http_protocol_ipv6": "disabled",
                    "http_put_response_hop_limit": 1,
                    "http_tokens": "optional",
                    "instance_metadata_tags": "disabled",
                    "state": "applied"
                },
                "monitoring": {
                    "state": "disabled"
                },
                "network_interfaces": [
                    {
                        "association": {
                            "ip_owner_id": "amazon",
                            "public_dns_name": "ec2-65-0-135-62.ap-south-1.compute.amazonaws.com",
                            "public_ip": "65.0.135.62"
                        },
                        "attachment": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "attachment_id": "eni-attach-07093f77cebcde1f7",
                            "delete_on_termination": true,
                            "device_index": 0,
                            "network_card_index": 0,
                            "status": "attached"
                        },
                        "description": "",
                        "groups": [
                            {
                                "group_id": "sg-04182bdfbfa17d831",
                                "group_name": "freedom"
                            }
                        ],
                        "interface_type": "interface",
                        "ipv6_addresses": [],
                        "mac_address": "0a:e0:b6:93:05:f8",
                        "network_interface_id": "eni-0163dfbfb1aa4c2fb",
                        "owner_id": "516234497646",
                        "private_dns_name": "ip-172-31-0-62.ap-south-1.compute.internal",
                        "private_ip_address": "172.31.0.62",
                        "private_ip_addresses": [
                            {
                                "association": {
                                    "ip_owner_id": "amazon",
                                    "public_dns_name": "ec2-65-0-135-62.ap-south-1.compute.amazonaws.com",
                                    "public_ip": "65.0.135.62"
                                },
                                "primary": true,
                                "private_dns_name": "ip-172-31-0-62.ap-south-1.compute.internal",
                                "private_ip_address": "172.31.0.62"
                            }
                        ],
                        "source_dest_check": true,
                        "status": "in-use",
                        "subnet_id": "subnet-0513e0192526a89ad",
                        "vpc_id": "vpc-04c6b7bd99f05c144"
                    }
                ],
                "placement": {
                    "availability_zone": "ap-south-1b",
                    "group_name": "",
                    "tenancy": "default"
                },
                "platform_details": "Linux/UNIX",
                "private_dns_name": "ip-172-31-0-62.ap-south-1.compute.internal",
                "private_dns_name_options": {
                    "enable_resource_name_dns_a_record": false,
                    "enable_resource_name_dns_aaaa_record": false,
                    "hostname_type": "ip-name"
                },
                "private_ip_address": "172.31.0.62",
                "product_codes": [],
                "public_dns_name": "ec2-65-0-135-62.ap-south-1.compute.amazonaws.com",
                "public_ip_address": "65.0.135.62",
                "root_device_name": "/dev/xvda",
                "root_device_type": "ebs",
                "security_groups": [
                    {
                        "group_id": "sg-04182bdfbfa17d831",
                        "group_name": "freedom"
                    }
                ],
                "source_dest_check": true,
                "state": {
                    "code": 16,
                    "name": "running"
                },
                "state_transition_reason": "",
                "subnet_id": "subnet-0513e0192526a89ad",
                "tags": {
                    "Name": "myapp-asg",
                    "aws:autoscaling:groupName": "myapp-asg"
                },
                "usage_operation": "RunInstances",
                "usage_operation_update_time": "2022-07-04T09:33:50+00:00",
                "virtualization_type": "hvm",
                "vpc_id": "vpc-04c6b7bd99f05c144"
            },
            {
                "ami_launch_index": 1,
                "architecture": "x86_64",
                "block_device_mappings": [
                    {
                        "device_name": "/dev/xvda",
                        "ebs": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "delete_on_termination": true,
                            "status": "attached",
                            "volume_id": "vol-0a9568f429e2db564"
                        }
                    }
                ],
                "capacity_reservation_specification": {
                    "capacity_reservation_preference": "open"
                },
                "client_token": "e0e60722-3c4f-eded-1083-403ed45c797b",
                "cpu_options": {
                    "core_count": 1,
                    "threads_per_core": 1
                },
                "ebs_optimized": false,
                "ena_support": true,
                "enclave_options": {
                    "enabled": false
                },
                "hibernation_options": {
                    "configured": false
                },
                "hypervisor": "xen",
                "image_id": "ami-08df646e18b182346",
                "instance_id": "i-0d71471665b4545f1",
                "instance_type": "t2.micro",
                "key_name": "devops-class",
                "launch_time": "2022-07-04T09:33:50+00:00",
                "maintenance_options": {
                    "auto_recovery": "default"
                },
                "metadata_options": {
                    "http_endpoint": "enabled",
                    "http_protocol_ipv6": "disabled",
                    "http_put_response_hop_limit": 1,
                    "http_tokens": "optional",
                    "instance_metadata_tags": "disabled",
                    "state": "applied"
                },
                "monitoring": {
                    "state": "disabled"
                },
                "network_interfaces": [
                    {
                        "association": {
                            "ip_owner_id": "amazon",
                            "public_dns_name": "ec2-13-233-13-39.ap-south-1.compute.amazonaws.com",
                            "public_ip": "13.233.13.39"
                        },
                        "attachment": {
                            "attach_time": "2022-07-04T09:33:50+00:00",
                            "attachment_id": "eni-attach-0d84e324c829efd6f",
                            "delete_on_termination": true,
                            "device_index": 0,
                            "network_card_index": 0,
                            "status": "attached"
                        },
                        "description": "",
                        "groups": [
                            {
                                "group_id": "sg-04182bdfbfa17d831",
                                "group_name": "freedom"
                            }
                        ],
                        "interface_type": "interface",
                        "ipv6_addresses": [],
                        "mac_address": "0a:5b:a9:e5:2b:6c",
                        "network_interface_id": "eni-03b0bc58894cfe8ee",
                        "owner_id": "516234497646",
                        "private_dns_name": "ip-172-31-4-15.ap-south-1.compute.internal",
                        "private_ip_address": "172.31.4.15",
                        "private_ip_addresses": [
                            {
                                "association": {
                                    "ip_owner_id": "amazon",
                                    "public_dns_name": "ec2-13-233-13-39.ap-south-1.compute.amazonaws.com",
                                    "public_ip": "13.233.13.39"
                                },
                                "primary": true,
                                "private_dns_name": "ip-172-31-4-15.ap-south-1.compute.internal",
                                "private_ip_address": "172.31.4.15"
                            }
                        ],
                        "source_dest_check": true,
                        "status": "in-use",
                        "subnet_id": "subnet-0513e0192526a89ad",
                        "vpc_id": "vpc-04c6b7bd99f05c144"
                    }
                ],
                "placement": {
                    "availability_zone": "ap-south-1b",
                    "group_name": "",
                    "tenancy": "default"
                },
                "platform_details": "Linux/UNIX",
                "private_dns_name": "ip-172-31-4-15.ap-south-1.compute.internal",
                "private_dns_name_options": {
                    "enable_resource_name_dns_a_record": false,
                    "enable_resource_name_dns_aaaa_record": false,
                    "hostname_type": "ip-name"
                },
                "private_ip_address": "172.31.4.15",
                "product_codes": [],
                "public_dns_name": "ec2-13-233-13-39.ap-south-1.compute.amazonaws.com",
                "public_ip_address": "13.233.13.39",
                "root_device_name": "/dev/xvda",
                "root_device_type": "ebs",
                "security_groups": [
                    {
                        "group_id": "sg-04182bdfbfa17d831",
                        "group_name": "freedom"
                    }
                ],
                "source_dest_check": true,
                "state": {
                    "code": 16,
                    "name": "running"
                },
                "state_transition_reason": "",
                "subnet_id": "subnet-0513e0192526a89ad",
                "tags": {
                    "Name": "myapp-asg",
                    "aws:autoscaling:groupName": "myapp-asg"
                },
                "usage_operation": "RunInstances",
                "usage_operation_update_time": "2022-07-04T09:33:50+00:00",
                "virtualization_type": "hvm",
                "vpc_id": "vpc-04c6b7bd99f05c144"
            }
        ]
    }
}

PLAY RECAP ************************************************************************************************************************************************
localhost                  : ok=3    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %% [markdown]
# ### Printing public ip

# %%
$ cat main.yml 
---
- name: "Getting AutoScaling Instance Details"
  hosts: localhost
  vars:
    access_key: "AKIAXQMPZJZXGR6OFJWL"
    secret_key: "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"
    region: "ap-south-1"
    asg_name: "myapp-asg"
  tasks:
    - name: "Fetching Instance Details Of asg {{ asg_name }}"
      amazon.aws.ec2_instance_info:
        aws_secret_key: "{{ secret_key }}"
        aws_access_key: "{{ access_key }}"
        region: "{{ region }}"
        filters:
          "tag:aws:autoscaling:groupName": "{{ asg_name }}"
          instance-state-name: [ "running"]
      register: asginstance_info
        
    - name: "Debugging asginfo"
      debug:
        msg: "Instance ID: {{ item.instance_id }} Instance Public IP: {{item.public_ip_address}}"
      with_items: "{{ asginstance_info.instances }}"

# %%
$ ansible-playbook -i hosts main.yml

# %%
[DEPRECATION WARNING]: Ansible will require Python 3.8 or newer on the controller starting with Ansible 2.12. Current version: 3.7.10 (default, Jun  3 
2021, 00:02:01) [GCC 7.3.1 20180712 (Red Hat 7.3.1-13)]. This feature will be removed from ansible-core in version 2.12. Deprecation warnings can be 
disabled by setting deprecation_warnings=False in ansible.cfg.

PLAY [Getting AutoScaling Instance Details] ***************************************************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
ok: [localhost]

TASK [Fetching Instance Details Of asg myapp-asg] *********************************************************************************************************
ok: [localhost]

TASK [Debugging asginfo] **********************************************************************************************************************************

default'}}) => {
    "msg": "Instance ID: i-0d71471665b4545f1 Instance Public IP: 13.233.13.39"
}

# %% [markdown]
# ### Simplet file touch"

# %%
[ec2-user@ip-172-31-5-232 ~]$ cat main.yml 
---
- name: "Getting AutoScaling Instance Details"
  hosts: localhost
  vars:
    access_key: "AKIAXQMPZJZXGR6OFJWL"
    secret_key: "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"
    region: "ap-south-1"
    asg_name: "myapp-asg"
  tasks:
    - name: "Fetching Instance Details Of asg {{ asg_name }}"
      amazon.aws.ec2_instance_info:
        aws_secret_key: "{{ secret_key }}"
        aws_access_key: "{{ access_key }}"
        region: "{{ region }}"
        filters:
          "tag:aws:autoscaling:groupName": "{{ asg_name }}"
          instance-state-name: [ "running"]
      register: asginstance_info
        


    - name: "creating Inventry"
      add_host:
        name: "{{ item.public_ip_address }}"
        groups:
          - clb-backends
        ansible_host: "{{ item.public_ip_address }}"
        ansible_ssh_port: 22
        ansible_ssh_private_key_file: "aws.pem"
        ansible_ssh_common_args: "-o StrictHostKeyChecking=no"

      with_items: "{{ asginstance_info.instances }}"


- name: " Deploying website to Autoscaling group"
  hosts: clb-backends
  become: yes
  tasks:
    - name: "Simplet file touch"
      file:
        path: /tmp
        state: touch

# %%
$ ansible-playbook -i hosts main.yml

# %%
[DEPRECATION WARNING]: Ansible will require Python 3.8 or newer on the controller starting with Ansible 2.12. Current version: 3.7.10 (default, Jun  3 
2021, 00:02:01) [GCC 7.3.1 20180712 (Red Hat 7.3.1-13)]. This feature will be removed from ansible-core in version 2.12. Deprecation warnings can be 
disabled by setting deprecation_warnings=False in ansible.cfg.

PLAY [Getting AutoScaling Instance Details] ***************************************************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
ok: [localhost]

TASK [Fetching Instance Details Of asg myapp-asg] *********************************************************************************************************
ok: [localhost]

TASK [creating Inventry] 
TASK [Simplet file touch] *********************************************************************************************************************************
changed: [65.0.135.62]
changed: [13.233.13.39]
changed: [13.233.223.21]

PLAY RECAP ************************************************************************************************************************************************
13.233.13.39               : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
13.233.223.21              : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
65.0.135.62                : ok=2    changed=1    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
localhost                  : ok=3    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0

# %% [markdown]
# ## Deploying Website From Github To AutoScaling Group

# %%
$ cat main.yml 
---
- name: "Getting AutoScaling Instance Details"
  hosts: localhost
  vars:
    access_key: "AKIAXQMPZJZXGR6OFJWL"
    secret_key: "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"
    
  tasks:
    - name: "aaa"
      set_fact:
        asg_name: "myapp-asg"
        region: "ap-south-1"
        cacheable: yes
        

    - name: "Fetching Instance Details Of asg {{ asg_name }}"
      amazon.aws.ec2_instance_info:
        aws_secret_key: "{{ secret_key }}"
        aws_access_key: "{{ access_key }}"
        region: "{{ region }}"
        filters:
          "tag:aws:autoscaling:groupName": "{{ asg_name }}"
          instance-state-name: [ "running"]
      register: asginstance_info

    - name: "creating Inventry"
      add_host:
        name: "{{ item.public_ip_address }}"
        groups:
          - clb-backends
        ansible_host: "{{ item.public_ip_address }}"
        ansible_ssh_user: "ec2-user"
        ansible_ssh_port: 22
        ansible_ssh_private_key_file: "aws.pem"
        ansible_ssh_common_args: "-o StrictHostKeyChecking=no"

      with_items: "{{ asginstance_info.instances }}"


- name: " Deploying Website From Github To AutoScaling Group region is {{ hostvars['localhost']['region'] }}"
  hosts: clb-backends
  become: yes
  serial: 1
  vars:
    git_url: https://github.com/jinumona/aws-elb-site.git
    git_dir: /var/website/
    health_check_delay: 45
  tasks:
    - name: "Deployment- Installing packages"
      yum:
        name: 
          - httpd
          - git
          - php
        state: present


    - name: "cloning files from Git"
      git:
        dest: "{{ git_dir }}"
        repo: "{{ git_url}}"
      register: git_status

    - name: "Offloading instances(Stopping httpd) from Autoscaling Group {{ hostvars['localhost']['asg_name'] }}"
      when: git_status.changed == true
      service:
       name: httpd
       state: stopped


    - name: "Copying site files to Document root"
      when: git_status.changed == true
      copy: 
        dest: /var/www/html
        src: "{{ git_dir }}"
        owner: apache
        group: apache
        remote_src: yes

    - name: " Starting httpd service"
      when: git_status.changed == true
      service:
        name: httpd
        state: restarted
        enabled: yes

    - name: "Waiting for health check pass"
      when: git_status.changed == true
      wait_for:
        sleep: "{{ health_check_delay }}"

# %%
$ ansible-playbook -i hosts main.yml 
[DEPRECATION WARNING]: Ansible will require Python 3.8 or newer on the controller starting with Ansible 2.12. Current version: 3.7.10 (default, Jun  3 
2021, 00:02:01) [GCC 7.3.1 20180712 (Red Hat 7.3.1-13)]. This feature will be removed from ansible-core in version 2.12. Deprecation warnings can be 
disabled by setting deprecation_warnings=False in ansible.cfg.

PLAY [Getting AutoScaling Instance Details] ***************************************************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
ok: [localhost]

TASK [aaa] ************************************************************************************************************************************************
ok: [localhost]

TASK [Fetching Instance Details Of asg myapp-asg] *********************************************************************************************************
ok: [localhost]

TASK [creating Inventry] **********************************************************************************************************************************
ok: [localhost] => (item={'ami_launch_index': 0, 'image_id': 'ami-08df646e18b182346', 'instance_id': 'i-0dfe8858c515fff0e', 'instance_type': 't2.micro', 'key_name': 'devops-class', 'launch_time': '2022-07-04T09:33:50+00:00', 'monitoring': {'state': 'disabled'}, 'placement': {'availability_zone': 'ap-south-1a', 'group_name': '', 'tenancy': 'default'}, 'private_dns_name': 'ip-172-31-40-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.40.62', 'product_codes': [], 'public_dns_name': 'ec2-13-233-223-21.ap-south-1.compute.amazonaws.com', 'public_ip_address': '13.233.223.21', 'state': {'code': 16, 'name': 'running'}, 'state_transition_reason': '', 'subnet_id': 'subnet-0c76e66f9fa438375', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'architecture': 'x86_64', 'block_device_mappings': [{'device_name': '/dev/xvda', 'ebs': {'attach_time': '2022-07-04T09:33:50+00:00', 'delete_on_termination': True, 'status': 'attached', 'volume_id': 'vol-0da77109d288c431f'}}], 'client_token': '29260722-3c50-e379-c734-865d642dbe9d', 'ebs_optimized': False, 'ena_support': True, 'hypervisor': 'xen', 'network_interfaces': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-13-233-223-21.ap-south-1.compute.amazonaws.com', 'public_ip': '13.233.223.21'}, 'attachment': {'attach_time': '2022-07-04T09:33:50+00:00', 'attachment_id': 'eni-attach-0b7ae5ab48e77715a', 'delete_on_termination': True, 'device_index': 0, 'status': 'attached', 'network_card_index': 0}, 'description': '', 'groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'ipv6_addresses': [], 'mac_address': '02:d8:d7:18:f9:58', 'network_interface_id': 'eni-07f1e0bf9ccaf9b55', 'owner_id': '516234497646', 'private_dns_name': 'ip-172-31-40-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.40.62', 'private_ip_addresses': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-13-233-223-21.ap-south-1.compute.amazonaws.com', 'public_ip': '13.233.223.21'}, 'primary': True, 'private_dns_name': 'ip-172-31-40-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.40.62'}], 'source_dest_check': True, 'status': 'in-use', 'subnet_id': 'subnet-0c76e66f9fa438375', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'interface_type': 'interface'}], 'root_device_name': '/dev/xvda', 'root_device_type': 'ebs', 'security_groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'source_dest_check': True, 'tags': {'Name': 'myapp-asg', 'aws:autoscaling:groupName': 'myapp-asg'}, 'virtualization_type': 'hvm', 'cpu_options': {'core_count': 1, 'threads_per_core': 1}, 'capacity_reservation_specification': {'capacity_reservation_preference': 'open'}, 'hibernation_options': {'configured': False}, 'metadata_options': {'state': 'applied', 'http_tokens': 'optional', 'http_put_response_hop_limit': 1, 'http_endpoint': 'enabled', 'http_protocol_ipv6': 'disabled', 'instance_metadata_tags': 'disabled'}, 'enclave_options': {'enabled': False}, 'platform_details': 'Linux/UNIX', 'usage_operation': 'RunInstances', 'usage_operation_update_time': '2022-07-04T09:33:50+00:00', 'private_dns_name_options': {'hostname_type': 'ip-name', 'enable_resource_name_dns_a_record': False, 'enable_resource_name_dns_aaaa_record': False}, 'maintenance_options': {'auto_recovery': 'default'}})
ok: [localhost] => (item={'ami_launch_index': 0, 'image_id': 'ami-08df646e18b182346', 'instance_id': 'i-034707f95171eb446', 'instance_type': 't2.micro', 'key_name': 'devops-class', 'launch_time': '2022-07-04T09:33:50+00:00', 'monitoring': {'state': 'disabled'}, 'placement': {'availability_zone': 'ap-south-1b', 'group_name': '', 'tenancy': 'default'}, 'private_dns_name': 'ip-172-31-0-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.0.62', 'product_codes': [], 'public_dns_name': 'ec2-65-0-135-62.ap-south-1.compute.amazonaws.com', 'public_ip_address': '65.0.135.62', 'state': {'code': 16, 'name': 'running'}, 'state_transition_reason': '', 'subnet_id': 'subnet-0513e0192526a89ad', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'architecture': 'x86_64', 'block_device_mappings': [{'device_name': '/dev/xvda', 'ebs': {'attach_time': '2022-07-04T09:33:50+00:00', 'delete_on_termination': True, 'status': 'attached', 'volume_id': 'vol-03d61f6f3afa81395'}}], 'client_token': 'e0e60722-3c4f-eded-1083-403ed45c797b', 'ebs_optimized': False, 'ena_support': True, 'hypervisor': 'xen', 'network_interfaces': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-65-0-135-62.ap-south-1.compute.amazonaws.com', 'public_ip': '65.0.135.62'}, 'attachment': {'attach_time': '2022-07-04T09:33:50+00:00', 'attachment_id': 'eni-attach-07093f77cebcde1f7', 'delete_on_termination': True, 'device_index': 0, 'status': 'attached', 'network_card_index': 0}, 'description': '', 'groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'ipv6_addresses': [], 'mac_address': '0a:e0:b6:93:05:f8', 'network_interface_id': 'eni-0163dfbfb1aa4c2fb', 'owner_id': '516234497646', 'private_dns_name': 'ip-172-31-0-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.0.62', 'private_ip_addresses': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-65-0-135-62.ap-south-1.compute.amazonaws.com', 'public_ip': '65.0.135.62'}, 'primary': True, 'private_dns_name': 'ip-172-31-0-62.ap-south-1.compute.internal', 'private_ip_address': '172.31.0.62'}], 'source_dest_check': True, 'status': 'in-use', 'subnet_id': 'subnet-0513e0192526a89ad', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'interface_type': 'interface'}], 'root_device_name': '/dev/xvda', 'root_device_type': 'ebs', 'security_groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'source_dest_check': True, 'tags': {'aws:autoscaling:groupName': 'myapp-asg', 'Name': 'myapp-asg'}, 'virtualization_type': 'hvm', 'cpu_options': {'core_count': 1, 'threads_per_core': 1}, 'capacity_reservation_specification': {'capacity_reservation_preference': 'open'}, 'hibernation_options': {'configured': False}, 'metadata_options': {'state': 'applied', 'http_tokens': 'optional', 'http_put_response_hop_limit': 1, 'http_endpoint': 'enabled', 'http_protocol_ipv6': 'disabled', 'instance_metadata_tags': 'disabled'}, 'enclave_options': {'enabled': False}, 'platform_details': 'Linux/UNIX', 'usage_operation': 'RunInstances', 'usage_operation_update_time': '2022-07-04T09:33:50+00:00', 'private_dns_name_options': {'hostname_type': 'ip-name', 'enable_resource_name_dns_a_record': False, 'enable_resource_name_dns_aaaa_record': False}, 'maintenance_options': {'auto_recovery': 'default'}})
ok: [localhost] => (item={'ami_launch_index': 1, 'image_id': 'ami-08df646e18b182346', 'instance_id': 'i-0d71471665b4545f1', 'instance_type': 't2.micro', 'key_name': 'devops-class', 'launch_time': '2022-07-04T09:33:50+00:00', 'monitoring': {'state': 'disabled'}, 'placement': {'availability_zone': 'ap-south-1b', 'group_name': '', 'tenancy': 'default'}, 'private_dns_name': 'ip-172-31-4-15.ap-south-1.compute.internal', 'private_ip_address': '172.31.4.15', 'product_codes': [], 'public_dns_name': 'ec2-13-233-13-39.ap-south-1.compute.amazonaws.com', 'public_ip_address': '13.233.13.39', 'state': {'code': 16, 'name': 'running'}, 'state_transition_reason': '', 'subnet_id': 'subnet-0513e0192526a89ad', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'architecture': 'x86_64', 'block_device_mappings': [{'device_name': '/dev/xvda', 'ebs': {'attach_time': '2022-07-04T09:33:50+00:00', 'delete_on_termination': True, 'status': 'attached', 'volume_id': 'vol-0a9568f429e2db564'}}], 'client_token': 'e0e60722-3c4f-eded-1083-403ed45c797b', 'ebs_optimized': False, 'ena_support': True, 'hypervisor': 'xen', 'network_interfaces': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-13-233-13-39.ap-south-1.compute.amazonaws.com', 'public_ip': '13.233.13.39'}, 'attachment': {'attach_time': '2022-07-04T09:33:50+00:00', 'attachment_id': 'eni-attach-0d84e324c829efd6f', 'delete_on_termination': True, 'device_index': 0, 'status': 'attached', 'network_card_index': 0}, 'description': '', 'groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'ipv6_addresses': [], 'mac_address': '0a:5b:a9:e5:2b:6c', 'network_interface_id': 'eni-03b0bc58894cfe8ee', 'owner_id': '516234497646', 'private_dns_name': 'ip-172-31-4-15.ap-south-1.compute.internal', 'private_ip_address': '172.31.4.15', 'private_ip_addresses': [{'association': {'ip_owner_id': 'amazon', 'public_dns_name': 'ec2-13-233-13-39.ap-south-1.compute.amazonaws.com', 'public_ip': '13.233.13.39'}, 'primary': True, 'private_dns_name': 'ip-172-31-4-15.ap-south-1.compute.internal', 'private_ip_address': '172.31.4.15'}], 'source_dest_check': True, 'status': 'in-use', 'subnet_id': 'subnet-0513e0192526a89ad', 'vpc_id': 'vpc-04c6b7bd99f05c144', 'interface_type': 'interface'}], 'root_device_name': '/dev/xvda', 'root_device_type': 'ebs', 'security_groups': [{'group_name': 'freedom', 'group_id': 'sg-04182bdfbfa17d831'}], 'source_dest_check': True, 'tags': {'Name': 'myapp-asg', 'aws:autoscaling:groupName': 'myapp-asg'}, 'virtualization_type': 'hvm', 'cpu_options': {'core_count': 1, 'threads_per_core': 1}, 'capacity_reservation_specification': {'capacity_reservation_preference': 'open'}, 'hibernation_options': {'configured': False}, 'metadata_options': {'state': 'applied', 'http_tokens': 'optional', 'http_put_response_hop_limit': 1, 'http_endpoint': 'enabled', 'http_protocol_ipv6': 'disabled', 'instance_metadata_tags': 'disabled'}, 'enclave_options': {'enabled': False}, 'platform_details': 'Linux/UNIX', 'usage_operation': 'RunInstances', 'usage_operation_update_time': '2022-07-04T09:33:50+00:00', 'private_dns_name_options': {'hostname_type': 'ip-name', 'enable_resource_name_dns_a_record': False, 'enable_resource_name_dns_aaaa_record': False}, 'maintenance_options': {'auto_recovery': 'default'}})
[WARNING]: Invalid characters were found in group names but not replaced, use -vvvv to see details

PLAY [Deploying Website From Github To AutoScaling Group region is ap-south-1] ****************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
[WARNING]: Platform linux on host 13.233.223.21 is using the discovered Python interpreter at /usr/bin/python, but future installation of another Python
interpreter could change the meaning of that path. See https://docs.ansible.com/ansible-core/2.11/reference_appendices/interpreter_discovery.html for more
information.
ok: [13.233.223.21]

TASK [Deployment- Installing packages] ********************************************************************************************************************
ok: [13.233.223.21]

TASK [cloning files from Git] *****************************************************************************************************************************
changed: [13.233.223.21]

TASK [Offloading instances(Stopping httpd) from Autoscaling Group myapp-asg] ******************************************************************************
changed: [13.233.223.21]

TASK [Copying site files to Document root] ****************************************************************************************************************
changed: [13.233.223.21]

TASK [Starting httpd service] *****************************************************************************************************************************
changed: [13.233.223.21]

TASK [Waiting for health check pass] **********************************************************************************************************************
ok: [13.233.223.21]

PLAY [Deploying Website From Github To AutoScaling Group region is ap-south-1] ****************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
[WARNING]: Platform linux on host 65.0.135.62 is using the discovered Python interpreter at /usr/bin/python, but future installation of another Python
interpreter could change the meaning of that path. See https://docs.ansible.com/ansible-core/2.11/reference_appendices/interpreter_discovery.html for more
information.
ok: [65.0.135.62]

TASK [Deployment- Installing packages] ********************************************************************************************************************
ok: [65.0.135.62]

TASK [cloning files from Git] *****************************************************************************************************************************
changed: [65.0.135.62]

TASK [Offloading instances(Stopping httpd) from Autoscaling Group myapp-asg] ******************************************************************************
changed: [65.0.135.62]

TASK [Copying site files to Document root] ****************************************************************************************************************
changed: [65.0.135.62]

TASK [Starting httpd service] *****************************************************************************************************************************
changed: [65.0.135.62]

TASK [Waiting for health check pass] **********************************************************************************************************************
ok: [65.0.135.62]

PLAY [Deploying Website From Github To AutoScaling Group region is ap-south-1] ****************************************************************************

TASK [Gathering Facts] ************************************************************************************************************************************
[WARNING]: Platform linux on host 13.233.13.39 is using the discovered Python interpreter at /usr/bin/python, but future installation of another Python
interpreter could change the meaning of that path. See https://docs.ansible.com/ansible-core/2.11/reference_appendices/interpreter_discovery.html for more
information.
ok: [13.233.13.39]

TASK [Deployment- Installing packages] ********************************************************************************************************************
ok: [13.233.13.39]

TASK [cloning files from Git] *****************************************************************************************************************************
changed: [13.233.13.39]

TASK [Offloading instances(Stopping httpd) from Autoscaling Group myapp-asg] ******************************************************************************
changed: [13.233.13.39]

TASK [Copying site files to Document root] ****************************************************************************************************************
changed: [13.233.13.39]

TASK [Starting httpd service] *****************************************************************************************************************************
changed: [13.233.13.39]

TASK [Waiting for health check pass] **********************************************************************************************************************
ok: [13.233.13.39]

PLAY RECAP ************************************************************************************************************************************************
13.233.13.39               : ok=7    changed=4    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
13.233.223.21              : ok=7    changed=4    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
65.0.135.62                : ok=7    changed=4    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0   
localhost                  : ok=4    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
